# %%
import os
os.chdir("/content/gdrive/My Drive/METIS_IDS_PROJECT_01")
# !ls
# Out:
# get_to_git.ipynb

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd gdrive/My Drive/METIS_IDS_PROJECT_01
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/METIS_IDS_PROJECT_01'
# /content/gdrive/My Drive/METIS_IDS_PROJECT_01

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/METIS_IDS_PROJECT_01/.git/

# %%
# !git clone https://github.com/jefferygao1984/METIS_IDS_PROJECT.git
# Out:
# Cloning into 'METIS_IDS_PROJECT'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 47 (delta 26), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (47/47), done.

# %%
# !git remote set-url origin https://jefferygao1984:lightverse01@github.com/jefferygao1984/textbank.git
# !git remote -v
# Out:
# origin	https://jefferygao1984:lightverse01@github.com/jefferygao1984/textbank.git (fetch)
# origin	https://jefferygao1984:lightverse01@github.com/jefferygao1984/textbank.git (push)

# %%
# !git config --global user.email 'jeffrey.gao@kbs.edu.au'
# !git config --global user.name 'jefferygao1984'

# %%
git pull origin master
# !git add .
# !git commit -m '4th commit'
# Out:
#   File "<ipython-input-44-56f40968d683>", line 1
#     git pull origin master
#            ^
# SyntaxError: invalid syntax

# %%
# !git push origin master
# Out:
# To https://github.com/jefferygao1984/textbank.git
#  ! [rejected]        master -> master (non-fast-forward)
# error: failed to push some refs to 'https://jefferygao1984:lightverse01@github.com/jefferygao1984/textbank.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
