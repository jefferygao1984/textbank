# %%
import requests

url = 'https://raw.githubusercontent.com/jefferygao1984/textbank/main/Asimov_TheLastQuestion.txt'
response = requests.get(url)
# print(response.text)
corpus = response.text

'''
import base64
import requests

master = 'https://raw.githubusercontent.com/jefferygao1984/textbank/main/Asimov_TheLastQuestion.txt'
req = requests.get(master)
req = req.text
print(req)'

'''

import nltk

data=corpus.replace('\n', ' ')
data = data.upper()
data = data.split(' ')

fdist1 = nltk.FreqDist(data)
print (fdist1.most_common(50))
# Out:
# [('THE', 237), ('\r', 175), ('OF', 133), ('AND', 116), ('A', 100), ('TO', 96), ('IN', 60), ('WAS', 55), ('IT', 51), ('HAD', 45), ('BE', 42), ('FOR', 40), ('ALL', 40), ('THAT', 37), ('AC', 30), ('IS', 28), ('BUT', 27), ('HIS', 27), ('ON', 26), ('YOU', 26), ('HE', 25), ('ONE', 24), ('AS', 23), ('SAID', 23), ('ITS', 22), ('WITH', 22), ('WILL', 22), ('SAID,', 21), ('AT', 20), ('I', 20), ('HAVE', 19), ('ONLY', 19), ('MAN', 18), ('NOT', 18), ('"I', 18), ('STARS', 18), ('ZEE', 18), ('THEY', 16), ('THERE', 15), ('DATA', 15), ('WE', 15), ('GALAXY', 15), ('LAST', 14), ('EVEN', 14), ('BY', 13), ('INTO', 13), ('WERE', 13), ('ENERGY', 13), ('YEARS', 13), ('WHEN', 12)]

# %%
cov = df.cov()
cov.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row0_col0,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row1_col1,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row2_col2,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row3_col3,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row4_col4,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row5_col5,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row6_col6,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row7_col7,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row8_col8,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row0_col1,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row2_col7,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row3_col0,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row3_col4,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row8_col9,#T_a7a2472e_9f45_11eb_a3d9_0242ac1c0002row9_col6{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
# ...

# %%
import pandas as pd
import numpy as np

rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(1000, 10))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row0_col0,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row1_col1,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row2_col2,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row3_col3,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row4_col4,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row5_col5,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row6_col6,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row7_col7,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row8_col8,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row0_col1,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row2_col7,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row4_col3,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row8_col9,#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row9_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_a8820a6c_9f45_11eb_a3d9_0242ac1c0002row0_col2{
# ...

# %%
left = np.random.randint(3,10)
mid = np.random.randint(3,10)
right = np.random.randint(3,10)
A = np.random.rand(left,mid)
B = np.random.rand(mid,right)
A @ B
# Out:
# array([[0.96285651, 1.75791813, 1.72810478],
#        [1.44945204, 2.48232258, 1.49221275],
#        [0.78511983, 1.18594819, 0.91525781],
#        [1.36791539, 1.6688845 , 1.75678579],
#        [1.84173084, 2.40041125, 2.81921988]])
