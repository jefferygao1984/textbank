# %%
import os
os.chdir("/content/gdrive/My Drive/GitTest")
# !ls
# Out:
# git.ipynb  Metis_IDS_prework.ipynb

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/GitTest
# Out:
# /content/gdrive/My Drive/GitTest

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/Colab Notebooks/.git/

# %%
# !git remote add origin https://jefferygao1984:lightverse01@github.com/jefferygao1984/textbank.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://jefferygao1984:lightverse01@github.com/jefferygao1984/Metis-KPAU/IDS1_190421.git (fetch)
# origin	https://jefferygao1984:lightverse01@github.com/jefferygao1984/Metis-KPAU/IDS1_190421.git (push)

# %%
# !git config --global user.email 'jeffrey.gao@kbs.edu.au'
# !git config --global user.name 'jefferygao1984'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master 22617c1] First commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin master
# Out:
# remote: Not Found
# fatal: repository 'https://jefferygao1984:lightverse01@github.com/jefferygao1984/Metis-KPAU/IDS1_190421.git/' not found
