# %%
import os
os.chdir("/content/gdrive/My Drive/METIS_IDS_PROJECT_01")
# !ls
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-dd368a425479> in <module>()
#       1 import os
# ----> 2 os.chdir("/content/gdrive/My Drive/METIS_IDS_PROJECT_01")
#       3 get_ipython().system('ls')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/METIS_IDS_PROJECT_01'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/METIS_IDS_PROJECT_01
# Out:
# /content/gdrive/My Drive/METIS_IDS_PROJECT_01

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/METIS_IDS_PROJECT_01/.git/

# %%
# !git remote add origin https://jefferygao1984:lightverse01@github.com/jefferygao1984/METIS_IDS_PROJECT.git
# !git remote add origin https://jefferygao1984:lightverse01@github.com/jefferygao1984/METIS_IDS_PROJECT.git
# !git remote -v
# Out:
# origin	https://github.com/jefferygao1984/METIS_IDS_PROJECT.git (fetch)
# origin	https://github.com/jefferygao1984/METIS_IDS_PROJECT.git (push)

# %%
# !git config --global user.email 'jeffrey.gao@kbs.edu.au'
# !git config --global user.name 'jefferygao1984'

# %%
from datetime import datetime
now = datetime.now()
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
commit_msg = 'Latest commit at: ' + dt_string

# !git add .
# !git commit -m commit_msg
# Out:
# [master (root-commit) 3bdf177] commit_msg
#  2 files changed, 2 insertions(+)
#  create mode 100644 PredictiveAnalytics.ipynb
#  create mode 100644 git.ipynb

# %%
# !git push origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
