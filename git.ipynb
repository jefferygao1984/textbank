# %%
import os
os.chdir("/content/gdrive/My Drive/GitTest")
# !ls
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-ee45d11b5158> in <module>()
#       1 import os
# ----> 2 os.chdir("/content/gdrive/My Drive/GitTest")
#       3 get_ipython().system('ls')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/GitTest'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g4zpBdTY3ZTb9wEZPXrXsWBfs4OHjxaVvbR113Htx5ngtt1qiTe0OI

# %%
# %cd gdrive/My Drive/GitTest
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/GitTest'
# /content/gdrive/My Drive/GitTest

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/GitTest/.git/

# %%
# !git remote add origin https://jefferygao1984:lightverse01@github.com/jefferygao1984/textbank.git
# !git remote -v
# Out:
# origin	https://jefferygao1984:lightverse01@github.com/jefferygao1984/textbank.git (fetch)
# origin	https://jefferygao1984:lightverse01@github.com/jefferygao1984/textbank.git (push)

# %%
# !git config --global user.email 'jeffrey.gao@kbs.edu.au'
# !git config --global user.name 'jefferygao1984'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master (root-commit) c899ba9] First commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 Metis_IDS_prework.ipynb
#  create mode 100644 git.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 6.38 KiB | 1.28 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'master' on GitHub by visiting:
# remote:      https://github.com/jefferygao1984/textbank/pull/new/master
# remote:
# To https://github.com/jefferygao1984/textbank.git
#  * [new branch]      master -> master
